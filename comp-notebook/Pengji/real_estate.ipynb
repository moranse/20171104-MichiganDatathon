# %%
# Obviously
import pandas as pd
import numpy as np

# Plotting set-up
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import rc
# Command to reset plot styles to default: mpl.rcParams.update(mpl.rcParamsDefault)
plt.style.use('seaborn-poster')
mpl.rcParams['font.family'] = 'serif'
% matplotlib inline

# Other packages we might need
# ! pip install quandl
# import quandl

# Options
pd.set_option('display.height', 500)
pd.set_option('display.max_rows', 500)
data_folder = '../../data/'

pd.set_option('display.height', 500)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
estate = pd.read_csv(data_folder + 'real_estate.csv')
# Out:
# height has been deprecated.
#
# height has been deprecated.

# %%
# estate.head(20)

# %%
los = estate[estate['metro']=='Los Angeles-Long Beach-Anaheim' ]
los_Z=estate[estate['metro']=='Los Angeles-Long Beach-Anaheim' ]
los_Z=los_Z[los_Z['type']=='ZHVI']
# Austin=estate[estate['metro']=='Austin']
# los.head(20)
los_Z=los_Z.drop(los_Z.columns[7:184], axis = 1)
los_Z=los_Z.drop(los_Z.columns[0], axis = 1)
los_Z=los_Z.drop(los_Z.columns[0:6], axis = 1)
# los=los.drop(los.columns['type']=='ZRI', axis = 1)
# los=los.drop(los.columns[0], axis = 1)
# df1.iloc[3:]
# los_Z.head(200)
# Los Angeles-Long Beach-Anaheim
# Austin
# estate['metro']
type(los_Z.mean())
los_price_Z=los_Z.mean()
# print(los_price)
los_price_Z.plot()
plt.show()

# %%
los = estate[estate['metro']=='Los Angeles-Long Beach-Anaheim' ]
los_R=estate[estate['metro']=='Los Angeles-Long Beach-Anaheim' ]
los_R=los_R[los_R['type']=='ZRI']
# Austin=estate[estate['metro']=='Austin']
# los.head(20)
los_R=los_R.drop(los_R.columns[7:184], axis = 1)
los_R=los_R.drop(los_R.columns[0], axis = 1)
los_R=los_R.drop(los_R.columns[0:6], axis = 1)
# los=los.drop(los.columns['type']=='ZRI', axis = 1)
# los=los.drop(los.columns[0], axis = 1)
# df1.iloc[3:]
# los_Z.head(200)
# Los Angeles-Long Beach-Anaheim
# Austin
# estate['metro']
type(los_R.mean())
los_price_R=los_R.mean()
# print(los_price)
los_price_R.plot()
plt.show()

# %%
los['zipcode'].describe()
# Out:
# count      695.000000
# mean     91281.520863
# std       1037.941537
# min      90001.000000
# 25%      90278.000000
# 50%      91202.000000
# 75%      91792.000000
# max      93591.000000
# Name: zipcode, dtype: float64

# %%
Aus = estate[estate['metro']=='Austin' ]
Aus_R=estate[estate['metro']=='Austin' ]
Aus_R=Aus_R[Aus_R['type']=='ZRI']
# Austin=estate[estate['metro']=='Austin']
# los.head(20)
Aus_R=Aus_R.drop(Aus_R.columns[7:184], axis = 1)
Aus_R=Aus_R.drop(Aus_R.columns[0], axis = 1)
Aus_R=Aus_R.drop(Aus_R.columns[0:6], axis = 1)
# los=los.drop(los.columns['type']=='ZRI', axis = 1)
# los=los.drop(los.columns[0], axis = 1)
# df1.iloc[3:]
# Aus_R.head(200)
# Los Angeles-Long Beach-Anaheim
# Austin
# estate['metro']
type(Aus_R.mean())
los_price_Z=Aus_R.mean()
# print(los_price)
los_price_Z.plot()
plt.show()

# %%
Aus['zipcode'].describe()
Aus['zipcode'].head(20)
# Out:
# 39      78613
# 75      78704
# 80      78745
# 437     78758
# 439     78759
# 447     78741
# 494     78753
# 502     78664
# 543     78641
# 649     78748
# 782     78681
# 1047    78640
# 1610    78665
# 1765    78749
# 1983    78744
# 2222    78729
# 2374    78723
# 2509    78727
# 2512    78731
# 2681    78610
# Name: zipcode, dtype: int64
