# %%
# Obviously
import pandas as pd
import numpy as np

# Plotting set-up
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import rc
# Command to reset plot styles to default: mpl.rcParams.update(mpl.rcParamsDefault)
plt.style.use('seaborn-poster')
mpl.rcParams['font.family'] = 'serif'
% matplotlib inline

# Other packages we might need
#! pip install quandl
import quandl

# %%
# Shannon's api_key: WsKntRjuv1-2XqwgbWoy
! curl https://www.quandl.com/api/v3/datasets/FRED/GDP.csv?collapse=annual&rows=6&order=asc&column_index=1&api_key=WsKntRjuv1-2XqwgbWoy > test.csv
# ! curl -o https://www.quandl.com/api/v3/datasets/FRED/GDP.csv?collapse=annual&rows=6&order=asc&column_index=1&api_key=WsKntRjuv1-2XqwgbWoy

# %%
# Helper: https://docs.quandl.com/docs/python-time-series
mydata = quandl.get("ZILLOW/GDP")
mydata.plot()

# %% [markdown]
# Quandl:
# * Imports as dataframes

# %%
% ls data/
# Out:
# calendar.csv        get_data.sh*        listings.csv        neighbourhoods.csv  reviews.csv

# %%
pd.set_option('display.height', 500)
pd.set_option('display.max_rows', 500)
data_folder = 'data/'
listings = pd.read_csv(data_folder + 'listings.csv')
reviews = pd.read_csv(data_folder + 'reviews.csv')
calendar = pd.read_csv(data_folder + 'calendar.csv')
neighborhoods = pd.read_csv(data_folder + 'neighbourhoods.csv')
# Out:
# height has been deprecated.

# %%
correlations = listings.corr()
print(correlations.shape)
plt.imshow(listings.corr(),cmap="viridis",interpolation='nearest')
plt.colorbar()
plt.show()
#listings.columns.get_loc("review_scores_rating")
# Out:
# (34, 34)

# %%
plt.scatter(listings['reviews_per_month'],listings['review_scores_rating'])
plt.show()

# %% [markdown]
# What need to happen:
# 1. Checklist for cleaning data
# 2. How to quickly screen for interesting things
# 3. Plan for working through data

# %%
listings['verbose'] = listings['space'].str.len()
listings['verbose'].hist(by=listings['cancellation_policy'],figsize=(10,10))
plt.show()

# %%
df2 = pd.DataFrame({'X' : ['B', 'B', 'A', 'A'], 'Y' : [1, 2, 3, 4]})
df2
df2.groupby(['X']).sum()

# %%
listings.columns

# %%
list(listings['space'].unique())

# %%
len(listings['description'].loc[2])
# listings = listings.drop(['verbose'],axis=1)
# listings['verbose']

# %%
listings['review_scores_rating'].hist(by=listings['room_type'],figsize=(10,10))

# %%
listings['price'].hist(by=listings['neighbourhood_cleansed'],figsize=(15,15))

# %%
reviews['rev_len'] = reviews['comments'].str.len()

# %%
listings.join(reviews)
